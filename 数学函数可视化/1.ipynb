# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# $ f(t) =  e^{-t}  \space \cos( 2 \pi t)  $
#
# $ g(t) =   \cos( 2 \pi t)  $

# %%
def f(t):
    return np.exp(-t)* np.cos(2*np.pi*t)

def g(t):
    return np.cos(2*np.pi*t)

xrange = 2.0*np.pi

a = np.arange(0.0,xrange  , 0.02)
cc = plt.subplot(2,1,1)# (行数， 列数，当前区域)

plt.xticks(np.arange(0,xrange,np.pi/2))
cc.set_ylim(-1.1, 1.1)
plt.yticks([-1,0,1])

# _ = plt.yticks(ticks = [-1,0,1],ha
# = 'right')

_ = plt.xticks(ticks = np.arange(0,xrange+0.1 ,np.pi/2), \
labels = ['0',r'$\frac{1}{2}\pi$',r'$\pi$',r'$\frac{3}{2}\pi$',r'$2\pi$'] \
)

_=plt.grid(True, linestyle='-.')


plt.plot(a,f(a))
#------------------

  

plt.subplot(2,1,2)
plt.xticks(np.arange(0,xrange,np.pi/2))
_ = plt.xticks(ticks = np.arange(0,xrange+0.1 ,np.pi/2), \
labels = ['0',r'$\frac{1}{2}\pi$',r'$\pi$',r'$\frac{3}{2}\pi$',r'$2\pi$'] \
)
plt.plot(a,g(a),'g--')
plt.show()

# %%
def f(t):
    return np.exp(-1 *t*t) #* np.cos(2*np.pi*t)
def g(t):
    return np.cos(2*np.pi*t)
xrange = np.pi* 2.0
yrange = 3
a = np.arange(-xrange ,xrange  , 0.02)
cc = plt.subplot(2,1,1)# (行数， 列数，当前区域)
plt.xticks(np.arange(-xrange,xrange,np.pi/2))
cc.set_ylim(- yrange -0.1, yrange+0.1)
#plt.yticks([-1,0,1])
# _ = plt.yticks(ticks = [-1,0,1],ha = 'right')
_=plt.xticks(ticks = np.arange(0,xrange+0.1 ,np.pi/2), \
labels = ['0',r'$\frac{1}{2}\pi$',r'$\pi$',r'$\frac{3}{2}\pi$',r'$2\pi$'] \
)
_=plt.grid(True, linestyle='-.')
plt.plot(a,f(a))
#------------------

plt.subplot(2,1,2)
plt.xticks(np.arange(0,xrange,np.pi/2))
_ = plt.xticks(ticks = np.arange(0,xrange+0.1 ,np.pi/2), \
labels = ['0',r'$\frac{1}{2}\pi$',r'$\pi$',r'$\frac{3}{2}\pi$',r'$2\pi$'] \
)
_=plt.grid(True, linestyle='-.')
plt.plot(a,g(a),'g--')
plt.show()

# %% [markdown]
# $ g(x) = \frac{1}{\sqrt{2\pi}} e^{-x^2 /2}  $

# %%
def f(x):
    sigma=1
    return np.exp(- x*x/(2 *sigma**2))  /  (sigma**3 * 2* np.pi**(3/2))
def g(x):
    return np.exp(- x*x/2 )  /  ( 2* np.pi**(1/2))
xrange = np.pi* 2.0 ;yrange = 0.1
a = np.arange(-xrange ,xrange  , 0.02)
cc = plt.subplot(2,1,1)# (行数， 列数，当前区域)
plt.xticks(np.arange(-xrange,xrange,np.pi/2))
cc.set_ylim(- yrange -0.1, yrange+0.1)
#plt.yticks([-1,0,1]) 
# _ = plt.yticks(ticks = [-1,0,1],ha = 'right')
_ = plt.xticks(ticks = np.arange(0,xrange+0.1 ,np.pi/2), \
labels = ['0',r'$\frac{1}{2}\pi$',r'$\pi$',r'$\frac{3}{2}\pi$',r'$2\pi$'] \
)
_=plt.grid(True, linestyle='-.')

plt.plot(a,f(a))
plt.plot(a,g(a),'g--')
#------------------
plt.subplot(2,1,2)
plt.xticks(np.arange(0,xrange,np.pi/2))
_ = plt.xticks(ticks = np.arange(0,xrange+0.1 ,np.pi/2), \
labels = ['0',r'$\frac{1}{2}\pi$',r'$\pi$',r'$\frac{3}{2}\pi$',r'$2\pi$'] \
)
_=plt.grid(True, linestyle='-.')
plt.plot(a,g(a),'g--')
plt.show()

# %%
#多口圆管等价
import math
d1 = 40
n = 3

d2 = math.sqrt(d1**2 *n)
print(d2)
# Out:
# 69.2820323027551

# %%
def f(t):
    return np.cos(t)*np.sin(t) #* np.cos(2*np.pi*t)
def g(t):
    return np.cos(2*t)*np.cos(t) + np.sin(t)*np.sin(t)
xrange = np.pi* 2.0
yrange = 2
a = np.arange(-xrange ,xrange  , 0.02)

cc = plt.subplot(2,1,1)# (行数， 列数，当前区域)
plt.xticks(np.arange(-xrange,xrange,np.pi/2))
cc.set_ylim(- yrange -0.1, yrange+0.1)
#plt.yticks([-1,0,1])
# _ = plt.yticks(ticks = [-1,0,1],ha = 'right')
_ = plt.xticks(ticks = np.arange(0,xrange+0.1 ,np.pi/2), \
labels = ['0',r'$\frac{1}{2}\pi$',r'$\pi$',r'$\frac{3}{2}\pi$',r'$2\pi$'] \
)
_=plt.grid(True, linestyle='-.')
plt.plot(a,f(a))
#------------------

cc2=plt.subplot(2,1,2)
plt.xticks(np.arange(0,xrange,np.pi/2))
cc2.set_ylim(- yrange -0.1, yrange+0.1)
_ = plt.xticks(ticks = np.arange(0,xrange+0.1 ,np.pi/2), \
labels = ['0',r'$\frac{1}{2}\pi$',r'$\pi$',r'$\frac{3}{2}\pi$',r'$2\pi$'] \
)
_=plt.grid(True, linestyle='-.')
plt.plot(a,g(a),'g--')

plt.show()

# %%
def f(t):
    return np.cos(t)*np.cos(t) #* np.cos(2*np.pi*t)
def g(t):
    return np.cos(2*t)*np.cos(t) + np.sin(t)*np.sin(t)
xrange = np.pi* 2.0
yrange = 2
a = np.arange(-xrange ,xrange  , 0.02)

cc = plt.subplot(2,1,1)# (行数， 列数，当前区域)
plt.xticks(np.arange(-xrange,xrange,np.pi/2))
cc.set_ylim(- yrange -0.1, yrange+0.1)
#plt.yticks([-1,0,1])
# _ = plt.yticks(ticks = [-1,0,1],ha = 'right')
_ = plt.xticks(ticks = np.arange(0,xrange+0.1 ,np.pi/2), \
labels = ['0',r'$\frac{1}{2}\pi$',r'$\pi$',r'$\frac{3}{2}\pi$',r'$2\pi$'] \
)
_=plt.grid(True, linestyle='-.')
plt.plot(a,f(a))
#------------------

cc2=plt.subplot(2,1,2)
plt.xticks(np.arange(0,xrange,np.pi/2))
cc2.set_ylim(- yrange -0.1, yrange+0.1)
_ = plt.xticks(ticks = np.arange(0,xrange+0.1 ,np.pi/2), \
labels = ['0',r'$\frac{1}{2}\pi$',r'$\pi$',r'$\frac{3}{2}\pi$',r'$2\pi$'] \
)
_=plt.grid(True, linestyle='-.')
plt.plot(a,g(a),'g--')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

h = np.pi
r = h /(np.sqrt(6))
yrange = 5
def f(z):
    #原函数

    return  z/ ((r**2 + z**2)**(3/2)         ) +  (h-z)/(  (r**2 + (h-z)**2)**(3/2)  )  
def g(z):
    ##二阶导数

    return 15.0*z**3/(r**2 + z**2)**3.5 - 9.0*z/(r**2 + z**2)**2.5 + 15.0*(h - z)**3/(r**2 + (h - z)**2)**3.5 - 9.0*(h - z)/(r**2 + (h - z)**2)**2.5

xrange = np.pi* 2.0

a = np.arange(-xrange ,xrange  , 0.08)

cc = plt.subplot(2,1,1)# (行数， 列数，当前区域)
plt.xticks(np.arange(-xrange,xrange,np.pi/2))
cc.set_ylim(- yrange -0.1, yrange+0.1)
#plt.yticks([-1,0,1])
# _ = plt.yticks(ticks = [-1,0,1],ha = 'right')
_ = plt.xticks(ticks = np.arange(0,xrange+0.1 ,np.pi/2), \
labels = ['0',r'$\frac{1}{2}\pi$',r'$\pi$',r'$\frac{3}{2}\pi$',r'$2\pi$'] \
)
_=plt.grid(True, linestyle='-.')
plt.plot(a,f(a)*(h**2))
#Z 轴单位为 Q/(4 pi e0 h^2)
#------------------

cc2=plt.subplot(2,1,2)
plt.xticks(np.arange(-xrange,xrange,np.pi/2))
cc2.set_ylim(- yrange -0.1, yrange+0.1)
_ = plt.xticks(ticks = np.arange(0,xrange+0.1 ,np.pi/2), \
labels = ['0',r'$\frac{1}{2}\pi$',r'$\pi$',r'$\frac{3}{2}\pi$',r'$2\pi$'] \
)
_=plt.grid(True, linestyle='-')
plt.plot(a,g(a)*(h**2),'g--')

plt.show()

# %%
def f(z):
    r=1
    return np.log(z/r) # np.log () is Ln    , np.log10 as base 10 Log.
def g(t):
    return t
xrange = 30
yrange = 10
a = np.arange(-xrange ,xrange  , 0.1)
cc = plt.subplot(2,1,1)# (行数， 列数，当前区域)
plt.xticks(np.arange(-xrange,xrange,np.pi/2))
cc.set_ylim(- yrange -0.1, yrange+0.1)
#plt.yticks([-1,0,1])
# _ = plt.yticks(ticks = [-1,0,1],ha = 'right')
# _=plt.xticks(ticks = np.arange(0,xrange+0.1 ,np.pi/2), \
# labels = ['0',r'$\frac{1}{2}\pi$',r'$\pi$',r'$\frac{3}{2}\pi$',r'$2\pi$'] \
# )
#_=plt.grid(True, linestyle='-.')
plt.plot(a,f(a))
plt.plot(a,g(a))
#------------------


plt.show()
# Out:
# C:\Users\wk2024\AppData\Local\Temp\ipykernel_9096\2261673294.py:3: RuntimeWarning: invalid value encountered in log
#   return np.log(z/r) # np.log () is Ln    , np.log10 as base 10 Log.

# %%
def f(z):
    R=1
    return np.sqrt(R**2 + z**2)-R -(z-1)
def g(t):
    return t*0
xrange = 30
yrange = 1
a = np.arange(-xrange ,xrange  , 0.1)
cc = plt.subplot(2,1,1)# (行数， 列数，当前区域)
plt.xticks(np.arange(-xrange,xrange,np.pi/2))
cc.set_ylim(- yrange -0.1, yrange+0.1)
#plt.yticks([-1,0,1])
# _ = plt.yticks(ticks = [-1,0,1],ha = 'right')
# _=plt.xticks(ticks = np.arange(0,xrange+0.1 ,np.pi/2), \
# labels = ['0',r'$\frac{1}{2}\pi$',r'$\pi$',r'$\frac{3}{2}\pi$',r'$2\pi$'] \
# )
#_=plt.grid(True, linestyle='-.')
plt.plot(a,f(a))
plt.plot(a,g(a))
#------------------

# %%
import matplotlib.pyplot as plt
import numpy as np

R = 1
rho = 1
epsilon0 = 0.0001
yrange = rho*R**2/(2*epsilon0)+1000
def f(r):
    #

    return rho*R**3/(3* epsilon0* r)
    #返回numpy数组

def g(r):
    

    return rho*R**2/(2*epsilon0) - rho*r**2/(6*epsilon0)

xrange = np.pi* 2.0

a = np.arange(-xrange ,xrange*2  , 0.08)

cc = plt.subplot(2,1,1)# (行数， 列数，当前区域)
plt.xticks(np.arange(-xrange,xrange,np.pi/2))
cc.set_ylim(- yrange -0.1, yrange+0.1)
#plt.yticks([-1,0,1])
# _ = plt.yticks(ticks = [-1,0,1],ha = 'right')
_ = plt.xticks(ticks = np.arange(0,xrange+0.1 ,np.pi/2), \
labels = ['0',r'$\frac{1}{2}\pi$',r'$\pi$',r'$\frac{3}{2}\pi$',r'$2\pi$'] \
)
_=plt.grid(True, linestyle='-.')
plt.plot(a,f(a))
plt.plot(a,g(a),'g--')
#Z 轴单位为 Q/(4 pi e0 h^2)
#------------------

cc2=plt.subplot(2,1,2)
plt.xticks(np.arange(-xrange,xrange,np.pi/2))
cc2.set_ylim(- yrange -0.1, yrange+0.1)
_ = plt.xticks(ticks = np.arange(0,xrange+0.1 ,np.pi/2), \
labels = ['0',r'$\frac{1}{2}\pi$',r'$\pi$',r'$\frac{3}{2}\pi$',r'$2\pi$'] \
)
_=plt.grid(True, linestyle='-')

#=========================
f1= f(a)
g1= g(a)

condition = g1>f(R) 

merged_array = np.where(condition, g1,f1)

condition2 = a>0
#条件为真选左，否则选右， 语义同三元运算符 ? A:B
merged_array2 = np.where(condition2,merged_array,   np.zeros(236)  )
#=========================
plt.plot(a,merged_array2,'r')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

R = 1
rho = 1
sigma =1
a =1
epsilon0 = 0.0001
yrange = rho*R**2/(2*epsilon0)+1000
def f(y):
    #

    return sigma/(2*np.pi) *(np.sqrt(y**2+a**2) - y)
    #返回numpy数组

def g(y):
    

    return sigma/(2*np.pi) *(np.sqrt(y**2+a**2) + y)

xrange = np.pi* 2.0

a = np.arange(-xrange ,xrange*2  , 0.08)

cc = plt.subplot(2,1,1)# (行数， 列数，当前区域)
plt.xticks(np.arange(-xrange,xrange,np.pi/2))
cc.set_ylim(- yrange -0.1, yrange+0.1)
#plt.yticks([-1,0,1])
# _ = plt.yticks(ticks = [-1,0,1],ha = 'right')
_ = plt.xticks(ticks = np.arange(0,xrange+0.1 ,np.pi/2), \
labels = ['0',r'$\frac{1}{2}\pi$',r'$\pi$',r'$\frac{3}{2}\pi$',r'$2\pi$'] \
)
_=plt.grid(True, linestyle='-.')
plt.plot(a,f(a))
plt.plot(a,g(a),'g--')
#Z 轴单位为 Q/(4 pi e0 h^2)
#------------------

cc2=plt.subplot(2,1,2)
plt.xticks(np.arange(-xrange,xrange,np.pi/2))
cc2.set_ylim(- yrange -0.1, yrange+0.1)
_ = plt.xticks(ticks = np.arange(0,xrange+0.1 ,np.pi/2), \
labels = ['0',r'$\frac{1}{2}\pi$',r'$\pi$',r'$\frac{3}{2}\pi$',r'$2\pi$'] \
)
_=plt.grid(True, linestyle='-')

#=========================
f1= f(a)
g1= g(a)

condition = a>0

merged_array = np.where(condition, f1,g1)

# condition2 = a<0
# #条件为真选左，否则选右， 语义同三元运算符 ? A:B
# merged_array2 = np.where(condition2,merged_array,   np.zeros(236)  )
#=========================
plt.plot(a,merged_array,'r')

plt.show()

# %% [markdown]
# 软件滤波计算公式
#
# 当前滤波值 = a × 当前实际值 + (1 - a) × 先前滤波值
# a——滤波系数，取值范围为0-1之间。
#
#
# F = a/  (2πt)
# t——采样+计算时间（s）
#
#
# 例如信号中有20Hz的干扰信号，滤波计算周期t为1ms，则滤波系数需要小于0.125。
#
#     F = a/(2π * 0.001) < 20Hz
#     a < 0.125

# %%
import matplotlib.pyplot as plt
import numpy as np
from math import *

h = np.pi
r = h /(np.sqrt(6))




fc=2 #截止频率
Ts=0.02 #采样周期
b = 2*np.pi*fc*Ts
alpha = Ts / (Ts+ 1/(2*np.pi*fc))#b/b+1 #alpha
alpha = b / (b+1) #alpha
print("b",b)
print("a",alpha)


#t = np.linspace(0,0.01,500)
t =  np.arange(-0.1 ,5  , 0.02)
f1_t = 3*np.sin(2*np.pi*1*t)+1*np.sin(2*np.pi*4*t)
f2_t = f1_t.copy()#copy(f1_t)




f2_t[1] = f1_t[1]


#一阶低通滤波 #RC
for n in range(2,int(5/0.02)   ):
    f2_t[n] = f2_t[n-1]  + alpha*(  f1_t[n]- f2_t[n-1]    ) 





yrange = 5
def f(t):
    #原函数
    return  3*np.sin(2*np.pi*1*t)+1*np.sin(2*np.pi*4*t)
def g(z):
    ##二阶导数

    return 15.0*z**3/(r**2 + z**2)**3.5 - 9.0*z/(r**2 + z**2)**2.5 + 15.0*(h - z)**3/(r**2 + (h - z)**2)**3.5 - 9.0*(h - z)/(r**2 + (h - z)**2)**2.5

xrange = np.pi* 2.0

cc = plt.subplot(2,1,1)# (行数， 列数，当前区域)
plt.xticks(np.arange(-xrange,xrange,np.pi/2))
cc.set_ylim(- yrange -0.1, yrange+0.1)
cc.set_xlim(0-0.1, 5+0.1)
#plt.yticks([-1,0,1])
# _ = plt.yticks(ticks = [-1,0,1],ha = 'right')

# _ = plt.xticks(ticks = np.arange(0,xrange+0.1 ,np.pi/2), \
# labels = ['0',r'$\frac{1}{2}\pi$',r'$\pi$',r'$\frac{3}{2}\pi$',r'$2\pi$'] \
# )
_=plt.grid(True, linestyle='-.')
plt.plot(t,f1_t)
plt.plot(t,f2_t)
#Z 
#------------------

cc2=plt.subplot(2,1,2)
plt.xticks(np.arange(-xrange,xrange,np.pi/2))
cc2.set_ylim(- yrange -0.1, yrange+0.1)
cc2.set_xlim(0-0.1, 5+0.1)
# _ = plt.xticks(ticks = np.arange(0,xrange+0.1 ,np.pi/2), \
# labels = ['0',r'$\frac{1}{2}\pi$',r'$\pi$',r'$\frac{3}{2}\pi$',r'$2\pi$'] \
# )
_=plt.grid(True, linestyle='-')
plt.plot(t,f2_t,'g')

plt.show()
# Out:
# b 0.25132741228718347
# a 0.20084864266483685

# %%
fc=1 #截止频率
Ts=0.02 #采样周期
b = 2*np.pi*fc*Ts
alpha = Ts / (Ts+ 1/(2*np.pi*fc))#b/b+1 #alpha
alpha = b / b+1 #alpha

# %%
b
# Out:
# 0.12566370614359174

# %%
b/b+1
# Out:
# 2.0

# %%
b/(b+1)
# Out:
# 0.11163521170465973

# %%
import matplotlib.pyplot as plt
import numpy as np
from math import *
import control
h = np.pi
r = h /(np.sqrt(6))




fc=2 #截止频率
Ts=0.02 #采样周期
b = 2*np.pi*fc*Ts
alpha = Ts / (Ts+ 1/(2*np.pi*fc))#b/b+1 #alpha
alpha = b / (b+1) #alpha
print("b",b)
print("a",alpha)


#t = np.linspace(0,0.01,500)
t =  np.arange(-0.1 ,15  , 0.002)
f1_t = 3*np.sin(2*np.pi*10*t)+2*np.sin(2*np.pi*40*t) +1*np.sin(2*np.pi*120*t)
f2_t = f1_t.copy()#copy(f1_t)

f2_t[1] = f1_t[1]
#一阶低通滤波 #RC
for n in range(2,len(f1_t)   ):
    f2_t[n] = f2_t[n-1]  + alpha*(  f1_t[n]- f2_t[n-1]    ) 


#显示区域
yrange =20
drawxrange = 0.5
#----------
numerator = [1]
denominator = [0.01,1]
tf = control.tf(numerator,denominator)
_,impluse_resp = control.impulse_response(tf,T=1,T_num=int(1/0.002) )
print(f"卷积核长度 {len(impluse_resp)}")
#--------
f3_t = f1_t.copy()
print(f"数据长度  {len(f1_t)}")
f3_t = np.convolve(f1_t,impluse_resp ,'same')

xrange = np.pi* 2.0
cc = plt.subplot(2,1,1)# (行数， 列数，当前区域)
plt.xticks(np.arange(-xrange,xrange,np.pi/2))
cc.set_ylim(- yrange -0.1, yrange +0.1)
cc.set_xlim(0-0.1, drawxrange+0.1)
_=plt.grid(True, linestyle='-.')
plt.plot(t,f1_t,'b',alpha=0.4)
plt.plot(t,f2_t,'g',alpha=0.7)
#------------------
cc2=plt.subplot(2,1,2)
plt.xticks(np.arange(-xrange,xrange,np.pi/2))
cc2.set_ylim(- yrange -0.1, yrange+0.1)
cc2.set_xlim(0-0.1, drawxrange+0.1)
_=plt.grid(True, linestyle='-')
plt.plot(t,f1_t,'b',alpha=0.4)
#plt.plot(t[:len(f3_t)],f3_t)
#plt.plot(t,f3_t[:len(t)])
plt.plot(t,f3_t,'r',alpha=0.7)
plt.show()
# Out:
# b 0.25132741228718347
# a 0.20084864266483685
# 卷积核长度 500
# 数据长度  7550

# %% [markdown]
# # AUDIO

# %%
recreate_frequency =500/ 4 #hz
recreate_frequency
# Out:
# 125.0

# %%
import numpy as np
from scipy.fftpack import fft, ifft
#import librosa
import scipy.io.wavfile as wav

def read_wav(audio_path):
    '''使用scipy库下的方法读取音频文件wav,返回时间序列y（数据类型和声道数由文件本身决定）和采样率sr'''
    sr, y = wav.read(filename=audio_path)  #读取音频文件，返回音频采样率和时间序列
    return y, sr
 
def write_wav(y, sr, save_path):
    '''使用scipy库下的方法，将时间序列保存为wav格式，y是音频时间序列，sr是采样率，save_path="***.wav"'''
    wav.write(filename=save_path, rate=sr, data=np.array(np.clip(np.round(y), -2**15, 2**15-1), dtype=np.int16))

# %%
out_wav_int_16_s = to_int16(f1_t)

write_wav(out_wav_int_16_s, 500, 'aaa.wav')

# %%
print(f1_t)
# Out:
# [ 5.63337528e-15  2.33753378e+00  2.56005875e+00 ... -2.11813986e+00
#  -2.56005875e+00 -2.33753378e+00]

# %%
def to_int16(__in):
    _max_f = float(max(__in))
    return_list = __in.copy()
    for i in range(len(__in)):
        
        return_list[i] =  int(__in[i] / (_max_f) * 8192*2) #-6db 8192*2      #-12db 8192   #0db 
    return return_list

# %%
20* np.log10(4)
# Out:
# 12.041199826559248

# %%
def f(t):
    return np.sin(t)#*np.sin(t) #* np.cos(2*np.pi*t)
def g(t):
    #return np.cos(2*t)*np.cos(t) + np.sin(t)*np.sin(t)
    xi=0.13
    omega_n = 50
    omega_d = omega_n*np.sqrt(1-xi**2)
    print(f"omega_d={omega_d}")
    theta = np.arctan( np.sqrt(1-xi**2) /xi )
    #二阶阻尼震荡
    return 1 - (1.0/np.sqrt(1 - xi**2))*np.exp(-1 * xi * omega_n * t) *np.sin(omega_d * t + theta  )
xrange = np.pi* 2.0
yrange = 2
a = np.arange(0,xrange  , 0.002)

cc = plt.subplot(1,1,1)# (行数， 列数，当前区域) 
plt.xticks(np.arange(-xrange,xrange,np.pi/2))
cc.set_ylim(- yrange -0.1, yrange+0.1)
#plt.yticks([-1,0,1])
# _ = plt.yticks(ticks = [-1,0,1],ha = 'right')
_ = plt.xticks(ticks = np.arange(0,xrange+0.1 ,np.pi/2), \
labels = ['0',r'$\frac{1}{2}\pi$',r'$\pi$',r'$\frac{3}{2}\pi$',r'$2\pi$'] \
)
_=plt.grid(True, linestyle='-.')
plt.plot(a,f(a),alpha=0.3)
plt.plot(a,g(a),'g-',alpha=0.9)
# Out:
# omega_d=49.575699692490474

# %% [markdown]
# (exp(2*t) - 1)*exp(-3*t)*Heaviside(t)/2

# %%
def f(t):
    return np.sin(t)#*np.sin(t) #* np.cos(2*np.pi*t)
def g(t):
    #return np.cos(2*t)*np.cos(t) + np.sin(t)*np.sin(t)

    #响应G(t)
    #return (np.exp(2*t) - 1)*np.exp(-3*t)/2
    return 0.500500250083354*(np.exp(2*t) - 1.002002001334)*np.exp(-3*t)*np.heaviside(t - 0.00099999999999997,1)
xrange = np.pi* 2.0
yrange = 0.5
a = np.arange(0,xrange  , 0.002)

cc = plt.subplot(1,1,1)# (行数， 列数，当前区域) 
plt.xticks(np.arange(-xrange,xrange,np.pi/2))
cc.set_ylim(- yrange -0.1, yrange+0.1)
#plt.yticks([-1,0,1])
# _ = plt.yticks(ticks = [-1,0,1],ha = 'right')
_ = plt.xticks(ticks = np.arange(0,xrange+0.1 ,np.pi/2), \
labels = ['0',r'$\frac{1}{2}\pi$',r'$\pi$',r'$\frac{3}{2}\pi$',r'$2\pi$'] \
)
_=plt.grid(True, linestyle='-.')
plt.plot(a,f(a),alpha=0.3)
plt.plot(a,g(a),'g-',alpha=0.9)
# Out:
# omega_d=49.575699692490474
